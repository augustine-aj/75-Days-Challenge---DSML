# %% [markdown]
# # Day 9: Advanced Data Visualization with Seaborn
#
# In today's lesson, we focus on `Seaborn`, a powerful visualization library in Python that makes it easy to create aesthetically pleasing and informative statistical graphics.
#
# ---
# ## Objectives:
# - Learn how to create more complex and aesthetically pleasing visualizations with **Seaborn**.
# - Explore **Seaborn** for statistical data visualization.
#
# ### Topics to Cover:
# 1. **Introduction to Seaborn**
# 2. **Creating Categorical Plots**
# 3. **Creating Relational Plots**
# 4. **Visualizing Distributions**
# 5. **Pairplots for Multivariate Data Visualization**
#
# ---
#
# ### 1. Introduction to Seaborn
# **Seaborn** is a powerful visualization library built on top of **Matplotlib**. It provides a high-level interface for drawing attractive and informative statistical graphics. **Seaborn** simplifies the process of creating complex visualizations and is particularly well-suited for visualizing statistical relationships and istributions.
# on**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tips = sns.load_dataset('tips')

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Creating Categorical Plots
#
# #### Bar Plot
# Bar plots are useful for comparing quantities across different categories.

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.title('Average Total Bill by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Average Total Bill')
plt.savefig('Bar_Plot-Day9.png')
plt.show()

# %% [markdown]
# #### Box Plot
# Box plots provide a graphical representation of the distribution of numerical data through their quartiles.

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title('Total Bill Distribution by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill')
plt.savefig('Box_Plot-Day9.png')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Creating Relational Plots
# #### Scatter Plot
# Scatter plots are useful for exploring the relationship between two numerical variables.

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('Total Bill vs. Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.savefig('Scatter_Plot-Day9.png')
plt.show()

# %% [markdown]
# #### Line Plot
# Line plots can show trends over time.

# %%
sns.lineplot(x='time', y='total_bill', data=tips, estimator='mean', ci=None)
plt.title('Average Total Bill by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Average Total Bill')
plt.savefig('Line_Plot-Day9.png')
plt.show()
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_16420\2268171388.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='time', y='total_bill', data=tips, estimator='mean', ci=None)

# %% [markdown]
# ### 4. Visualizing Distributions
# #### Distribution Plot
# Distribution plots visualize the distribution of a continuous variable.

# %%
sns.histplot(tips['total_bill'], bins=20,)
plt.title('Total Bill Distribution')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.savefig('Distribution_Plot-Day9.png')
plt.show()

# %% [markdown]
# #### KDE Plot
# KDE (Kernel Density Estimate) plots show the probability density of a continuous variable.

# %%
sns.kdeplot(tips['total_bill'], shade=True)
plt.title('KDE of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.savefig('KDE_Plot-Day9.png')
plt.show()
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_16420\3307176472.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True)

# %% [markdown]
# ### 5. Pairplots for Multivariate Data Visualization
# Pairplots allow us to visualize pairwise relationships in a dataset.

# %%
sns.pairplot(tips, hue='time')
plt.title('Pairplot of Tips Dataset')
plt.savefig('Pair_Plot-Day9.png')
plt.show()

# %% [markdown]
# ## Exercises:
#
# #### 1. Visualize the distribution of a numeric column using Seaborn’s distplot.

# %%
sns.histplot(tips['total_bill'], bins=20, kde=True)
plt.title('Total Bill Distribution with KDE')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.savefig('Hist_KDE_Plot-Day9.png')
plt.show()

# %% [markdown]
# #### 2. Create a boxplot to compare the distributions of a numeric variable across different categories.

# %%
sns.boxplot(x='time', y='total_bill', data=tips)
plt.title('Total Bill Distribution by Time')
plt.xlabel('Time of Day')
plt.ylabel('Total Bill')
plt.savefig('Custom_Box_Plot-Day9.png')
plt.show()

# %% [markdown]
# #### 3. Use pairplot to visualize pairwise relationships in the dataset.

# %%
sns.pairplot(tips, hue='day')
plt.title('Pairplot of Tips Dataset by Day')
plt.savefig('Custom_Pair_Plot-Day9.png')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusion
#
# Today’s exploration into Seaborn has significantly enhanced my understanding of statistical data visualization. 🌟
#
# Key Takeaways:
#
# Aesthetic Visualizations: Seaborn allows for the creation of beautiful and complex statistical plots easily.
# Powerful Plotting Tools: I successfully created categorical, relational, and distribution plots, each serving distinct purposes in data exploration.
# Pairplot Exploration: Utilizing pairplots helped visualize pairwise relationships in multivariate datasets, providing deeper insights.
# Customization: The integration with Matplotlib allows for further customization of plots to enhance their clarity and appeal.
# I’m excited to continue this journey into advanced data analysis techniques! 💻📊

# %% [markdown]
# ---
