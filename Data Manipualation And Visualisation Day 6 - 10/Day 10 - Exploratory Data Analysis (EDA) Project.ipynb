# %% [markdown]
# # Day 10: Exploratory Data Analysis (EDA) Project
#
# ## 🎯 Objectives:
#
# Apply the skills you've learned to perform `exploratory data analysis (EDA)` on a real-world dataset.
# Combine `Pandas` for `data manipulation` and `Matplotlib/Seaborn` for `data visualization`.
#
# ---
#
# ## 📝 Project Steps:
# #### 1. Choose a Dataset:
# You can use a dataset from Kaggle or any CSV file you have available for analysis.
#
# #### 2. Load the Dataset and Inspect its Structure:
# Use `Pandas` to load the dataset and inspect its structure to understand the data.

# %%
import pandas as pd

df = pd.read_csv("D:/75 Days Challenge/Day_6_bmi_dataset.csv")

df.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     161      89      4
# 1   Male     179     127      4
# 2   Male     172     139      5
# 3   Male     153     104      5
# 4   Male     165      68      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  400 non-null    object
#  1   Height  400 non-null    int64
#  2   Weight  400 non-null    int64
#  3   Index   400 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 12.6+ KB

# %%
df.describe()
# Out:
#            Height      Weight       Index
# count  400.000000  400.000000  400.000000
# mean   170.362500  106.060000    3.737500
# std     16.574011   32.362242    1.370507
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    171.000000  106.500000    4.000000
# 75%    184.000000  136.250000    5.000000
# max    199.000000  160.000000    5.000000

# %% [markdown]
# #### 3. Clean the Dataset:
# Handle `missing values`, `remove outliers`, or make other necessary data cleaning tasks to prepare the data for analysis.

# %%
df.fillna(method='ffill', inplace=True)

df = df[df['Height'] < df['Height'].quantile(0.99)]
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_3632\2016688045.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     161      89      4
# 1   Male     179     127      4
# 2   Male     172     139      5
# 3   Male     153     104      5
# 4   Male     165      68      2

# %% [markdown]
# #### 4. Analyze the Dataset:
# Use `Pandas` `grouping`, `filtering`, and `sorting` functions to explore the dataset further.

# %%
grouped_data = df.groupby('Gender').mean()

# %%
print("Grouped Data by Gender (Mean):\n")
grouped_data
# Out:
# Grouped Data by Gender (Mean):
#             Height      Weight     Index
# Gender
# Female  170.390863  105.071066  3.675127
# Male    169.184615  107.117949  3.856410

# %%
filtered_data = df[df['Weight'] > 100]

# %%
print("\nFiltered Data (Weight > 100):\n")
filtered_data
# Out:
# Filtered Data (Weight > 100):
#     Gender  Height  Weight  Index
# 1     Male     179     127      4
# 2     Male     172     139      5
# 3     Male     153     104      5
# 6     Male     182     108      4
# 7     Male     179     130      5
# ..     ...     ...     ...    ...
# 395   Male     166     160      5
# 396   Male     145     130      5
# 397   Male     178     138      5
# 398   Male     168     158      5
# 399   Male     161     155      5
#
# [220 rows x 4 columns]

# %%
sorted_data = df.sort_values(by='Weight', ascending=False)

# %%
print("\nSorted Data by Weight (Descending):\n")
sorted_data.head()
# Out:
# Sorted Data by Weight (Descending):
#      Gender  Height  Weight  Index
# 160    Male     178     160      5
# 161  Female     184     160      5
# 71     Male     168     160      5
# 395    Male     166     160      5
# 387  Female     164     160      5

# %% [markdown]
# #### 5. Visualize Key Relationships and Trends:
# Use `Matplotlib` or `Seaborn` to create visualizations and analyze key relationships within the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x='Height', y='Weight', data=df)
plt.title('Relationship between Height and Weight')
plt.savefig('Scatter_Day-10.png')
plt.show()

sns.barplot(x='Gender', y='Height', data=df)
plt.title('Category-wise Comparison')
plt.savefig('Bar_Day-10.png')
plt.show()

sns.histplot(df['Weight'], bins=20, kde=True)
plt.title('Distribution of Weight')
plt.savefig('Hist_Day-10.png')
plt.show()

# %% [markdown]
# #### 6.Present Insights Based on the Analysis:
# Create a few summary plots and provide insights from the data analysis.

# %%
plt.plot(df.index, df['Height'])  # Plot height by row index (as a proxy for trends)
plt.title('Height Trend Over Rows')
plt.xlabel('Row Index')
plt.ylabel('Height')
plt.show()

correlation = df[['Height', 'Weight', 'Index']].corr()
sns.heatmap(correlation, annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🏆 Expected Outcome:
# By completing Day 10,
#
# Be proficient in manipulating data using Pandas.
# Understand how to clean, filter, and aggregate data for analysis.
# Be comfortable creating visualizations using Matplotlib and Seaborn.
# Be able to perform basic exploratory data analysis (EDA) on any dataset.

# %% [markdown]
# ---
#
# ##📈 Exercises:
# #### 1. Load a Dataset:
#
# Load a dataset and inspect its structure.

# %%
df = pd.read_csv("D:/75 Days Challenge/Day_6_bmi_dataset.csv")
df.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     161      89      4
# 1   Male     179     127      4
# 2   Male     172     139      5
# 3   Male     153     104      5
# 4   Male     165      68      2

# %% [markdown]
# #### 2. Handle Missing Values:
#
# Handle missing values in the dataset using forward fill.

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_3632\3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %% [markdown]
# #### 3. Group and Aggregate Data:
# Group the dataset by a categorical column and calculate the mean of numeric columns.

# %%
grouped_data = df.groupby('Gender').mean()
grouped_data
# Out:
#          Height  Weight  Index
# Gender
# Female  170.810  104.93  3.650
# Male    169.915  107.19  3.825

# %% [markdown]
# #### 4. Create a Visualization:
#
# Use Seaborn to create a scatter plot that shows the relationship between two numeric variables.

# %%
sns.scatterplot(x='Height', y='Weight', data=df)
plt.title('Relationship between Numeric Column1 and Numeric Column2')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusion:
#
# Day 10 has been a comprehensive dive into Exploratory Data Analysis (EDA), providing me with the opportunity to apply data manipulation and visualization skills on a real-world dataset. By cleaning and analyzing data using Pandas, and visualizing trends with Matplotlib and Seaborn, I gained a deeper understanding of how to uncover insights and patterns within datasets.
#
# This practical experience has made me proficient in performing EDA, and I’m now comfortable exploring, cleaning, and visualizing data to support decision-making. I look forward to applying these skills in more complex projects! 🚀

# %% [markdown]
# ---
