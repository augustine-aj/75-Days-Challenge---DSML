# %% [markdown]
# # Day 12: Create Advanced Visualizations 📊
#
# ---
#
# ## Objectives:
# - Develop insightful and advanced visualizations using `Matplotlib`, `Seaborn`, and `Plotly`.
# - Choose appropriate visualization techniques for different types of data.
# - Analyze visual patterns and trends to draft meaningful insights.
#
# ---
#
#
# ## Tasks:
# ### 1. Visual Exploration:
# ### Visualize Key Relationships:
#
# - Use `scatter plots`, `bar plots`, and `box plots` to investigate relationships between key variables.
# - Start with basic plots and move to more advanced visualizations, such as joint plots or facet grids, to explore bivariate or multivariate relationships.
# #### Advanced Visualization Code:

# %%
import pandas as pd

df = pd.read_csv("D:/75 Days Challenge/Day_6_bmi_dataset.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(x='Height', y='Weight', data=df, hue='Gender', height=6, aspect=1.5)
plt.title("Height vs Weight with Regression Line")
plt.show()

# %%
sns.boxplot(x='Gender', y='Weight', data=df, palette='Set3')
plt.title("Weight Distribution by Gender")
plt.show()
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_14016\3299869072.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.pairplot(df, hue='Gender', markers=["o", "s"], palette="husl")
plt.title("Pairplot for Multivariate Data Exploration")
plt.show()

# %%
df_corr = df[['Height', 'Weight', 'Index']]
corr = df_corr.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### 2. Design Visual Aesthetics:
# ### Enhance Plot Aesthetics:
#
# Customize your plots with `titles`, `labels`, `legends`, and `color schemes` to make them visually appealing.
# Use `Seaborn's` built-in themes or `Matplotlib` customization options to create `professional-looking plots`.
# #### Advanced Aesthetics Code:

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Gender', y='Weight', data=df, palette='Blues_d')
ax.set_title("Weight Comparison by Gender", fontsize=16)
ax.set_xlabel("Gender", fontsize=12)
ax.set_ylabel("Weight (kg)", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0, linewidths=1, linecolor='black')
plt.title("Correlation Matrix with Aesthetic Improvements")
plt.show()

# %% [markdown]
# ### 3. Advanced Interactive Visualizations:
# Explore `interactive visualizations` using libraries like Plotly, which provide dynamic visuals that allow users to hover over data points for additional insights. This can help in presentations or reports where viewers need more interaction with the data.
#
# #### Interactive Visualization Code:

# %%
import plotly.express as px

fig = px.scatter(df, x='Height', y='Weight', color='Gender', title='Height vs Weight Interactive Scatter Plot')
fig.show()

# Interactive Heatmap
fig = px.imshow(corr, text_auto=True, color_continuous_scale='Viridis')
fig.update_layout(title='Interactive Correlation Heatmap')
fig.show()

# %% [markdown]
# ### 4. Analysis of Visual Patterns:
# - Identify Patterns and Trends:
#
# Analyze trends and relationships revealed by your visualizations. For instance, does the correlation heatmap show any strong positive or negative correlations?
# - Document Insights:
#
# For each plot, note down key observations and trends. For example, if the regression line in the scatter plot indicates a strong relationship between height and weight, document that observation for later analysis.
# ### 5. Professional Development:
# - Study Data Visualization Best Practices:
#
# Read up on best practices to improve your visuals' clarity and effectiveness. Focus on improving the storytelling aspect of your visualizations, ensuring they communicate the insights clearly.
# - Engage with the Data Visualization Community:
#
# Share one of your visualizations on LinkedIn or data science forums, requesting feedback on your work. This will allow you to engage with a broader audience and gather insights for improvement.
#
#
# ---
#
#
# ## Conclusion:
# By the end of Day 12, you'll have created multiple insightful and aesthetically appealing visualizations that help communicate key patterns and relationships in your data. Your skills in using both static and interactive visualization libraries will be strengthened, providing you with a powerful toolkit for data analysis.
#
#
# ---
